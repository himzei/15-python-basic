# %%
x = 10 

if x == 10:
    print("10입니다")
# Out:
# 10입니다

# %%
x = 10 

if x == 10:
print("10입니다")
# Out:
#   Cell In[2], line 4
#     print("10입니다")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
x = 10 

if x == 10:
    pass
print("10입니다")
# Out:
# 10입니다

# %%
x = 10 

if x == 10:
    print("x에 들어있는 숫자는")
    print("10입니다")
# Out:
# x에 들어있는 숫자는
# 10입니다

# %%
x = 10 

if x == 10:
    print("x에 들어있는 숫자는")
print("10입니다")
# Out:
# x에 들어있는 숫자는
# 10입니다

# %%
x = 5 

if x == 10:
    print("x에 들어있는 숫자는")
    

print("10입니다")
# Out:
# 10입니다

# %%
# 중첩 if 조건문 사용하기 
# x = 15
# x = 10
x = 20

if x >= 10:
    print("10 이상입니다.")

    if x == 10: 
        print("10입니다.")
    
    if x == 20: 
        print("20입니다")
# Out:
# 10 이상입니다.
# 20입니다

# %%
x = int(input("숫자를 입력하세요"))

if x == 10: 
    print("10입니다.")

if x == 20: 
    print("20입니다")
# Out:
# 10입니다.
