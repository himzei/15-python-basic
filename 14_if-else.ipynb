# %%
# else 사용하기 
x = 5 

if x == 10: print("10입니다.")
else: print("10이 아닙니다.")
# Out:
# 10이 아닙니다.

# %%
x = 5 

if x == 10: 
    print("10입니다.")
else:
    print("x에 들어있는 숫자는") 
    print("10이 아닙니다.")
# Out:
# x에 들어있는 숫자는
# 10이 아닙니다.

# %%
x = 5 

if x == 10: 
    print("10입니다.")
else:
print("x에 들어있는 숫자는") 
    print("10이 아닙니다.")
# Out:
#   Cell In[3], line 6
#     print("x에 들어있는 숫자는")
#     ^
# IndentationError: expected an indented block after 'else' statement on line 5

# %%
x = 5 

if x == 10: 
    print("10입니다.")
else:
    print("x에 들어있는 숫자는") 

print("10이 아닙니다.")
# Out:
# x에 들어있는 숫자는
# 10이 아닙니다.

# %%
# if 조건문의 동작 방식 알아보기 


if True: 
    print("참")
else: 
    print("거짓")

if False: 
    print("참")
else: 
    print("거짓")
# Out:
# 참
# 거짓

# %%
if None: 
    print("참")
else: 
    print("거짓")

bool(None)
# Out:
# 거짓
# False

# %%
if 0: 
    print("참")
else: 
    print("거짓")
# Out:
# 거짓

# %%
if 1: 
    print("참")
else: 
    print("거짓")
# Out:
# 참

# %%
if "hello": 
    print("참")
else: 
    print("거짓")
# Out:
# 참

# %%
if "": 
    print("참")
else: 
    print("거짓")
# Out:
# 거짓

# %%
if [1]: 
    print("참")
else: 
    print("거짓")
# Out:
# 참

# %%
x = 10 
y = 20 

if x == 10 and y == 20:
    print('참')
else:
    print("거짓")
# Out:
# 참

# %%
# 10이상이고 20미만이 숫자는 참
x = int(input("숫자를 입력하세요 : "))

# if x >= 10 and x <= 20: 
#     print("참")
# else: 
#     print("거짓")


if 10 <= x and x <= 20: 
     print("참")
else: 
    print("거짓")
# Out:
# 참

# %%
x = int(input("숫자를 입력하세요 : "))

if 10 <= x <= 20:
    print("참")
else: 
    print("거짓")
# Out:
# 참
